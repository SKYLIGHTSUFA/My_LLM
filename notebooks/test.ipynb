# %%
a = list("asdasd")
a
# Out:
# ['a', 's', 'd', 'a', 's', 'd']

# %%
token_id = {' ': 0, 'Е': 1, 'а': 2, 'в': 3, 'е': 4, 'ж': 5, 'и': 6, 'к': 7, 'м': 8, 'н': 9, 'т': 10, 'у': 11, 'Еж': 12, 'Ежи': 13, 'Ежик': 14, 'Ежик ': 15, 'Ежик в': 16, 'Ежик в ': 17, 'Ежик в т': 18, 'Ежик в ту': 19, 'Ежик в тум': 20, 'Ежик в тума': 21, 'Ежик в тумам': 22, 'Ежик в тумамн': 23, 'Ежик в тумамне': 24}
"Е" in token_id
# Out:
# True

# %%
text = "Ежик в тумамне"
symbols = list(text)
''.join(symbols[:0])
# Out:
# ''

# %%
a
